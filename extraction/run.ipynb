# %%
import importlib
import downloader
import extractor
import threading

importlib.reload(downloader)
importlib.reload(extractor)
# Out:
# c:\Projetos\mineracao_arquivos_epstein_2026\extraction\extractor.py:32: SyntaxWarning: invalid escape sequence '\{'
#   while not os.path.exists(self.download_dir + f'\{curr_file}'):
# c:\Projetos\mineracao_arquivos_epstein_2026\extraction\extractor.py:35: SyntaxWarning: invalid escape sequence '\{'
#   with pdfplumber.open(self.download_dir + f'\{curr_file}') as pdf:
# c:\Projetos\mineracao_arquivos_epstein_2026\extraction\extractor.py:41: SyntaxWarning: invalid escape sequence '\{'
#   os.remove(self.download_dir + f'\{curr_file}')
# <module 'extractor' from 'c:\\Projetos\\mineracao_arquivos_epstein_2026\\extraction\\extractor.py'>

# %%
wd = downloader.Downloader()

# %%
extract = extractor.Extractor()

# %%
dataset=1

# %%
wd.get(f'https://www.justice.gov/epstein/doj-disclosures/data-set-{dataset}-files')

# %%
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException
import time

file_list = []

while True:
    file_links = wd.driver.find_elements(By.CSS_SELECTOR, 'div.item-list > ul > li > div.views-field.views-field-title > span.field-content > a')
    file_list = file_list + [item.get_attribute('innerHTML') for item in file_links]
    time.sleep(3)
    try:
        next_page = wd.driver.find_element(By.CSS_SELECTOR, 'nav.usa-pagination > ul > li.usa-pagination__arrow:nth-last-child(2) > a.usa-pagination__link.usa-pagination__next-page')
        wd.driver.execute_script('document.querySelector("nav.usa-pagination > ul > li.usa-pagination__arrow:nth-last-child(2) > a.usa-pagination__link.usa-pagination__next-page").click()')
    except NoSuchElementException:
        break

# %%
file_list
# Out:
# ['EFTA00002642.pdf',
#  'EFTA00002643.pdf',
#  'EFTA00002644.pdf',
#  'EFTA00002645.pdf',
#  'EFTA00002646.pdf',
#  'EFTA00002647.pdf',
#  'EFTA00002648.pdf',
#  'EFTA00002649.pdf',
#  'EFTA00002650.pdf',
#  'EFTA00002651.pdf',
#  'EFTA00002652.pdf',
#  'EFTA00002653.pdf',
#  'EFTA00002654.pdf',
#  'EFTA00002655.pdf',
#  'EFTA00002656.pdf',
#  'EFTA00002657.pdf',
#  'EFTA00002658.pdf',
#  'EFTA00002659.pdf',
#  'EFTA00002660.pdf',
#  'EFTA00002661.pdf',
#  'EFTA00002662.pdf',
#  'EFTA00002663.pdf',
#  'EFTA00002664.pdf',
#  'EFTA00002665.pdf',
#  'EFTA00002666.pdf',
#  'EFTA00002667.pdf',
#  'EFTA00002668.pdf',
#  'EFTA00002669.pdf',
#  'EFTA00002670.pdf',
#  'EFTA00002671.pdf',
#  'EFTA00002672.pdf',
#  'EFTA00002673.pdf',
#  'EFTA00002674.pdf',
#  'EFTA00002675.pdf',
#  'EFTA00002676.pdf',
#  'EFTA00002677.pdf',
#  'EFTA00002678.pdf',
#  'EFTA00002679.pdf',
#  'EFTA00002680.pdf',
#  'EFTA00002681.pdf',
#  'EFTA00002682.pdf',
#  'EFTA00002683.pdf',
#  'EFTA00002684.pdf',
#  'EFTA00002685.pdf',
#  'EFTA00002686.pdf',
#  'EFTA00002687.pdf',
#  'EFTA00002688.pdf',
#  'EFTA00002689.pdf',
#  'EFTA00002690.pdf',
#  'EFTA00002691.pdf',
#  'EFTA00002692.pdf',
#  'EFTA00002693.pdf',
#  'EFTA00002694.pdf',
#  'EFTA00002695.pdf',
#  'EFTA00002696.pdf',
#  'EFTA00002697.pdf',
#  'EFTA00002698.pdf',
#  'EFTA00002699.pdf',
#  'EFTA00002700.pdf',
#  'EFTA00002701.pdf',
#  'EFTA00002702.pdf',
#  'EFTA00002703.pdf',
#  'EFTA00002704.pdf',
#  'EFTA00002705.pdf',
#  'EFTA00002706.pdf',
#  'EFTA00002707.pdf',
#  'EFTA00002708.pdf',
#  'EFTA00002709.pdf',
#  'EFTA00002710.pdf',
#  'EFTA00002711.pdf',
#  'EFTA00002712.pdf',
#  'EFTA00002713.pdf',
#  'EFTA00002714.pdf',
#  'EFTA00002715.pdf',
#  'EFTA00002716.pdf',
#  'EFTA00002717.pdf',
#  'EFTA00002718.pdf',
#  'EFTA00002719.pdf',
#  'EFTA00002720.pdf',
#  'EFTA00002721.pdf',
#  'EFTA00002722.pdf',
#  'EFTA00002723.pdf',
#  'EFTA00002724.pdf',
#  'EFTA00002725.pdf',
#  'EFTA00002726.pdf',
#  'EFTA00002727.pdf',
#  'EFTA00002728.pdf',
#  'EFTA00002729.pdf',
#  'EFTA00002730.pdf',
#  'EFTA00002731.pdf',
#  'EFTA00002732.pdf',
#  'EFTA00002733.pdf',
#  'EFTA00002734.pdf',
#  'EFTA00002735.pdf',
#  'EFTA00002736.pdf',
#  'EFTA00002737.pdf',
#  'EFTA00002738.pdf',
#  'EFTA00002739.pdf',
#  'EFTA00002740.pdf',
#  'EFTA00002741.pdf',
#  'EFTA00002742.pdf',
#  'EFTA00002743.pdf',
#  'EFTA00002744.pdf',
#  'EFTA00002745.pdf',
#  'EFTA00002746.pdf',
#  'EFTA00002747.pdf',
#  'EFTA00002748.pdf',
#  'EFTA00002749.pdf',
#  'EFTA00002750.pdf',
#  'EFTA00002751.pdf',
#  'EFTA00002752.pdf',
#  'EFTA00002753.pdf',
#  'EFTA00002754.pdf',
#  'EFTA00002755.pdf',
#  'EFTA00002756.pdf',
#  'EFTA00002757.pdf',
#  'EFTA00002758.pdf',
#  'EFTA00002759.pdf',
#  'EFTA00002760.pdf',
#  'EFTA00002761.pdf',
#  'EFTA00002762.pdf',
#  'EFTA00002763.pdf',
#  'EFTA00002764.pdf',
#  'EFTA00002765.pdf',
#  'EFTA00002766.pdf',
#  'EFTA00002767.pdf',
#  'EFTA00002768.pdf',
#  'EFTA00002769.pdf',
#  'EFTA00002770.pdf',
#  'EFTA00002771.pdf',
#  'EFTA00002772.pdf',
#  'EFTA00002773.pdf',
#  'EFTA00002774.pdf',
#  'EFTA00002775.pdf',
#  'EFTA00002776.pdf',
#  'EFTA00002777.pdf',
#  'EFTA00002778.pdf',
#  'EFTA00002779.pdf',
#  'EFTA00002780.pdf',
#  'EFTA00002781.pdf',
#  'EFTA00002782.pdf',
#  'EFTA00002783.pdf',
#  'EFTA00002784.pdf',
#  'EFTA00002785.pdf',
#  'EFTA00002786.pdf',
#  'EFTA00002787.pdf',
#  'EFTA00002788.pdf',
#  'EFTA00002789.pdf',
#  'EFTA00002790.pdf',
#  'EFTA00002791.pdf',
#  'EFTA00002792.pdf',
#  'EFTA00002793.pdf',
#  'EFTA00002794.pdf',
#  'EFTA00002795.pdf',
#  'EFTA00002796.pdf',
#  'EFTA00002797.pdf',
#  'EFTA00002798.pdf',
#  'EFTA00002799.pdf',
#  'EFTA00002800.pdf',
#  'EFTA00002801.pdf',
#  'EFTA00002802.pdf',
#  'EFTA00002803.pdf',
#  'EFTA00002804.pdf',
#  'EFTA00002805.pdf',
#  'EFTA00002806.pdf',
#  'EFTA00002807.pdf',
#  'EFTA00002808.pdf',
#  'EFTA00002809.pdf',
#  'EFTA00002810.pdf',
#  'EFTA00002811.pdf',
#  'EFTA00002812.pdf',
#  'EFTA00002813.pdf',
#  'EFTA00002814.pdf',
#  'EFTA00002815.pdf',
#  'EFTA00002816.pdf',
#  'EFTA00002817.pdf',
#  'EFTA00002818.pdf',
#  'EFTA00002819.pdf',
#  'EFTA00002820.pdf',
#  'EFTA00002821.pdf',
#  'EFTA00002822.pdf',
#  'EFTA00002823.pdf',
#  'EFTA00002824.pdf',
#  'EFTA00002825.pdf',
#  'EFTA00002826.pdf',
#  'EFTA00002827.pdf',
#  'EFTA00002828.pdf',
#  'EFTA00002829.pdf',
#  'EFTA00002830.pdf',
#  'EFTA00002831.pdf',
#  'EFTA00002832.pdf',
#  'EFTA00002833.pdf',
#  'EFTA00002834.pdf',
#  'EFTA00002835.pdf',
#  'EFTA00002836.pdf',
#  'EFTA00002837.pdf',
#  'EFTA00002838.pdf',
#  'EFTA00002839.pdf',
#  'EFTA00002840.pdf',
#  'EFTA00002841.pdf',
#  'EFTA00002842.pdf',
#  'EFTA00002843.pdf',
#  'EFTA00002844.pdf',
#  'EFTA00002845.pdf',
#  'EFTA00002846.pdf',
#  'EFTA00002847.pdf',
#  'EFTA00002848.pdf',
#  'EFTA00002849.pdf',
#  'EFTA00002850.pdf',
#  'EFTA00002851.pdf',
#  'EFTA00002852.pdf',
#  'EFTA00002853.pdf',
#  'EFTA00002854.pdf',
#  'EFTA00002855.pdf',
#  'EFTA00002856.pdf',
#  'EFTA00002857.pdf',
#  'EFTA00002858.pdf',
#  'EFTA00002859.pdf',
#  'EFTA00002860.pdf',
#  'EFTA00002861.pdf',
#  'EFTA00002862.pdf',
#  'EFTA00002863.pdf',
#  'EFTA00002864.pdf',
#  'EFTA00002865.pdf',
#  'EFTA00002866.pdf',
#  'EFTA00002867.pdf',
#  'EFTA00002868.pdf',
#  'EFTA00002869.pdf',
#  'EFTA00002870.pdf',
#  'EFTA00002871.pdf',
#  'EFTA00002872.pdf',
#  'EFTA00002873.pdf',
#  'EFTA00002874.pdf',
#  'EFTA00002875.pdf',
#  'EFTA00002876.pdf',
#  'EFTA00002877.pdf',
#  'EFTA00002878.pdf',
#  'EFTA00002879.pdf',
#  'EFTA00002880.pdf',
#  'EFTA00002881.pdf',
#  'EFTA00002882.pdf',
#  'EFTA00002883.pdf',
#  'EFTA00002884.pdf',
#  'EFTA00002885.pdf',
#  'EFTA00002886.pdf',
#  'EFTA00002887.pdf',
#  'EFTA00002888.pdf',
#  'EFTA00002889.pdf',
#  'EFTA00002890.pdf',
#  'EFTA00002891.pdf',
#  'EFTA00002892.pdf',
#  'EFTA00002893.pdf',
#  'EFTA00002894.pdf',
#  'EFTA00002895.pdf',
#  'EFTA00002896.pdf',
#  'EFTA00002897.pdf',
#  'EFTA00002898.pdf',
#  'EFTA00002899.pdf',
#  'EFTA00002900.pdf',
#  'EFTA00002901.pdf',
#  'EFTA00002902.pdf',
#  'EFTA00002903.pdf',
#  'EFTA00002904.pdf',
#  'EFTA00002905.pdf',
#  'EFTA00002906.pdf',
#  'EFTA00002907.pdf',
#  'EFTA00002908.pdf',
#  'EFTA00002909.pdf',
#  'EFTA00002910.pdf',
#  'EFTA00002911.pdf',
#  'EFTA00002912.pdf',
#  'EFTA00002913.pdf',
#  'EFTA00002914.pdf',
#  'EFTA00002915.pdf',
#  'EFTA00002916.pdf',
#  'EFTA00002917.pdf',
#  'EFTA00002918.pdf',
#  'EFTA00002919.pdf',
#  'EFTA00002920.pdf',
#  'EFTA00002921.pdf',
#  'EFTA00002922.pdf',
#  'EFTA00002923.pdf',
#  'EFTA00002924.pdf',
#  'EFTA00002925.pdf',
#  'EFTA00002926.pdf',
#  'EFTA00002927.pdf',
#  'EFTA00002928.pdf',
#  'EFTA00002929.pdf',
#  'EFTA00002930.pdf',
#  'EFTA00002931.pdf',
#  'EFTA00002932.pdf',
#  'EFTA00002933.pdf',
#  'EFTA00002934.pdf',
#  'EFTA00002935.pdf',
#  'EFTA00002936.pdf',
#  'EFTA00002937.pdf',
#  'EFTA00002938.pdf',
#  'EFTA00002939.pdf',
#  'EFTA00002940.pdf',
#  'EFTA00002941.pdf',
#  'EFTA00002942.pdf',
#  'EFTA00002943.pdf',
#  'EFTA00002944.pdf',
#  'EFTA00002945.pdf',
#  'EFTA00002946.pdf',
#  'EFTA00002947.pdf',
#  'EFTA00002948.pdf',
#  'EFTA00002949.pdf',
#  'EFTA00002950.pdf',
#  'EFTA00002951.pdf',
#  'EFTA00002952.pdf',
#  'EFTA00002953.pdf',
#  'EFTA00002954.pdf',
#  'EFTA00002955.pdf',
#  'EFTA00002956.pdf',
#  'EFTA00002957.pdf',
#  'EFTA00002958.pdf',
#  'EFTA00002959.pdf',
#  'EFTA00002960.pdf',
#  'EFTA00002961.pdf',
#  'EFTA00002962.pdf',
#  'EFTA00002963.pdf',
#  'EFTA00002964.pdf',
#  'EFTA00002965.pdf',
#  'EFTA00002966.pdf',
#  'EFTA00002967.pdf',
#  'EFTA00002968.pdf',
#  'EFTA00002969.pdf',
#  'EFTA00002970.pdf',
#  'EFTA00002971.pdf',
#  'EFTA00002972.pdf',
#  'EFTA00002973.pdf',
#  'EFTA00002974.pdf',
#  'EFTA00002975.pdf',
#  'EFTA00002976.pdf',
#  'EFTA00002977.pdf',
#  'EFTA00002978.pdf',
#  'EFTA00002979.pdf',
#  'EFTA00002980.pdf',
#  'EFTA00002981.pdf',
#  'EFTA00002982.pdf',
#  'EFTA00002983.pdf',
#  'EFTA00002984.pdf',
#  'EFTA00002985.pdf',
#  'EFTA00002986.pdf',
#  'EFTA00002987.pdf',
#  'EFTA00002988.pdf',
#  'EFTA00002989.pdf',
#  'EFTA00002990.pdf',
#  'EFTA00002991.pdf',
#  'EFTA00002992.pdf',
#  'EFTA00002993.pdf',
#  'EFTA00002994.pdf',
#  'EFTA00002995.pdf',
#  'EFTA00002996.pdf',
#  'EFTA00002997.pdf',
#  'EFTA00002998.pdf',
#  'EFTA00002999.pdf',
#  'EFTA00003000.pdf',
#  'EFTA00003001.pdf',
#  'EFTA00003002.pdf',
#  'EFTA00003003.pdf',
#  'EFTA00003004.pdf',
#  'EFTA00003005.pdf',
#  'EFTA00003006.pdf',
#  'EFTA00003007.pdf',
#  'EFTA00003008.pdf',
#  'EFTA00003009.pdf',
#  'EFTA00003010.pdf',
#  'EFTA00003011.pdf',
#  'EFTA00003012.pdf',
#  'EFTA00003013.pdf',
#  'EFTA00003014.pdf',
#  'EFTA00003015.pdf',
#  'EFTA00003016.pdf',
#  'EFTA00003017.pdf',
#  'EFTA00003018.pdf',
#  'EFTA00003019.pdf',
#  'EFTA00003020.pdf',
#  'EFTA00003021.pdf',
#  'EFTA00003022.pdf',
#  'EFTA00003023.pdf',
#  'EFTA00003024.pdf',
#  'EFTA00003025.pdf',
#  'EFTA00003026.pdf',
#  'EFTA00003027.pdf',
#  'EFTA00003028.pdf',
#  'EFTA00003029.pdf',
#  'EFTA00003030.pdf',
#  'EFTA00003031.pdf',
#  'EFTA00003032.pdf',
#  'EFTA00003033.pdf',
#  'EFTA00003034.pdf',
#  'EFTA00003035.pdf',
#  'EFTA00003036.pdf',
#  'EFTA00003037.pdf',
#  'EFTA00003038.pdf',
#  'EFTA00003039.pdf',
#  'EFTA00003040.pdf',
#  'EFTA00003041.pdf',
#  'EFTA00003042.pdf',
#  'EFTA00003043.pdf',
#  'EFTA00003044.pdf',
#  'EFTA00003045.pdf',
#  'EFTA00003046.pdf',
#  'EFTA00003047.pdf',
#  'EFTA00003048.pdf',
#  'EFTA00003049.pdf',
#  'EFTA00003050.pdf',
#  'EFTA00003051.pdf',
#  'EFTA00003052.pdf',
#  'EFTA00003053.pdf',
#  'EFTA00003054.pdf',
#  'EFTA00003055.pdf',
#  'EFTA00003056.pdf',
#  'EFTA00003057.pdf',
#  'EFTA00003058.pdf',
#  'EFTA00003059.pdf',
#  'EFTA00003060.pdf',
#  'EFTA00003061.pdf',
#  'EFTA00003062.pdf',
#  'EFTA00003063.pdf',
#  'EFTA00003064.pdf',
#  'EFTA00003065.pdf',
#  'EFTA00003066.pdf',
#  'EFTA00003067.pdf',
#  'EFTA00003068.pdf',
#  'EFTA00003069.pdf',
#  'EFTA00003070.pdf',
#  'EFTA00003071.pdf',
#  'EFTA00003072.pdf',
#  'EFTA00003073.pdf',
#  'EFTA00003074.pdf',
#  'EFTA00003075.pdf',
#  'EFTA00003076.pdf',
#  'EFTA00003077.pdf',
#  'EFTA00003078.pdf',
#  'EFTA00003079.pdf',
#  'EFTA00003080.pdf',
#  'EFTA00003081.pdf',
#  'EFTA00003082.pdf',
#  'EFTA00003083.pdf',
#  'EFTA00003084.pdf',
#  'EFTA00003085.pdf',
#  'EFTA00003086.pdf',
#  'EFTA00003087.pdf',
#  'EFTA00003088.pdf',
#  'EFTA00003089.pdf',
#  'EFTA00003090.pdf',
#  'EFTA00003091.pdf',
#  'EFTA00003092.pdf',
#  'EFTA00003093.pdf',
#  'EFTA00003094.pdf',
#  'EFTA00003095.pdf',
#  'EFTA00003096.pdf',
#  'EFTA00003097.pdf',
#  'EFTA00003098.pdf',
#  'EFTA00003099.pdf',
#  'EFTA00003100.pdf',
#  'EFTA00003101.pdf',
#  'EFTA00003102.pdf',
#  'EFTA00003103.pdf',
#  'EFTA00003104.pdf',
#  'EFTA00003105.pdf',
#  'EFTA00003106.pdf',
#  'EFTA00003107.pdf',
#  'EFTA00003108.pdf',
#  'EFTA00003109.pdf',
#  'EFTA00003110.pdf',
#  'EFTA00003111.pdf',
#  'EFTA00003112.pdf',
#  'EFTA00003113.pdf',
#  'EFTA00003114.pdf',
#  'EFTA00003115.pdf',
#  'EFTA00003116.pdf',
#  'EFTA00003117.pdf',
#  'EFTA00003118.pdf',
#  'EFTA00003119.pdf',
#  'EFTA00003120.pdf',
#  'EFTA00003121.pdf',
#  'EFTA00003122.pdf',
#  'EFTA00003123.pdf',
#  'EFTA00003124.pdf',
#  'EFTA00003125.pdf',
#  'EFTA00003126.pdf',
#  'EFTA00003127.pdf',
#  'EFTA00003128.pdf',
#  'EFTA00003129.pdf',
#  'EFTA00003130.pdf',
#  'EFTA00003131.pdf',
#  'EFTA00003132.pdf',
#  'EFTA00003133.pdf',
#  'EFTA00003134.pdf',
#  'EFTA00003135.pdf',
#  'EFTA00003136.pdf',
#  'EFTA00003137.pdf',
#  'EFTA00003138.pdf',
#  'EFTA00003139.pdf',
#  'EFTA00003140.pdf',
#  'EFTA00003141.pdf',
#  'EFTA00003142.pdf',
#  'EFTA00003143.pdf',
#  'EFTA00003144.pdf',
#  'EFTA00003145.pdf',
#  'EFTA00003146.pdf',
#  'EFTA00003147.pdf',
#  'EFTA00003148.pdf',
#  'EFTA00003149.pdf',
#  'EFTA00003150.pdf',
#  'EFTA00003151.pdf',
#  'EFTA00003152.pdf',
#  'EFTA00003153.pdf',
#  'EFTA00003154.pdf',
#  'EFTA00003155.pdf',
#  'EFTA00003156.pdf',
#  'EFTA00003157.pdf',
#  'EFTA00003158.pdf']

# %%
# extract.extract_from_files(dataset, file_list[544:])
# Out:
# Exceção: arquivo EFTA00002642.pdf
# Exceção: arquivo EFTA00002643.pdf
# Exceção: arquivo EFTA00002644.pdf
# Exceção: arquivo EFTA00002645.pdf
# Exceção: arquivo EFTA00002646.pdf
# Exceção: arquivo EFTA00002647.pdf
# Exceção: arquivo EFTA00002648.pdf
# Exceção: arquivo EFTA00002649.pdf
# Exceção: arquivo EFTA00002650.pdf
# Exceção: arquivo EFTA00002651.pdf
# Exceção: arquivo EFTA00002652.pdf
# Exceção: arquivo EFTA00002653.pdf
# Exceção: arquivo EFTA00002654.pdf
# Exceção: arquivo EFTA00002655.pdf
# Exceção: arquivo EFTA00002656.pdf
# Exceção: arquivo EFTA00002657.pdf
# Exceção: arquivo EFTA00002658.pdf
# Exceção: arquivo EFTA00002659.pdf
# Exceção: arquivo EFTA00002660.pdf
# Exceção: arquivo EFTA00002661.pdf
# Exceção: arquivo EFTA00002662.pdf

# %%
thread1 = threading.Thread(target=wd.download_all_dataset, args=(dataset,file_list))
thread2 = threading.Thread(target=extract.extract_from_files, args=(dataset,file_list))

# %%
thread2 = threading.Thread(target=extract.extract_from_files, args=(dataset,file_list))

# %%
thread1.start()
thread2.start()
# Out:
# Exception in thread Thread-12 (download_all_dataset):
# Traceback (most recent call last):
#   File "c:\Users\gdswm\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connection.py", line 199, in _new_conn
#     sock = connection.create_connection(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\gdswm\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\util\connection.py", line 85, in create_connection
#     raise err
#   File "c:\Users\gdswm\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\util\connection.py", line 73, in create_connection
#     sock.connect(sa)
# ConnectionRefusedError: [WinError 10061] Nenhuma conexão pôde ser feita porque a máquina de destino as recusou ativamente
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "c:\Users\gdswm\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py", line 789, in urlopen
#     response = self._make_request(
#                ^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\gdswm\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py", line 495, in _make_request
#     conn.request(
#   File "c:\Users\gdswm\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connection.py", line 441, in request
#     self.endheaders()
#   File "c:\Users\gdswm\AppData\Local\Programs\Python\Python312\Lib\http\client.py", line 1331, in endheaders
#     self._send_output(message_body, encode_chunked=encode_chunked)
#   File "c:\Users\gdswm\AppData\Local\Programs\Python\Python312\Lib\http\client.py", line 1091, in _send_output
#     self.send(msg)
#   File "c:\Users\gdswm\AppData\Local\Programs\Python\Python312\Lib\http\client.py", line 1035, in send
#     self.connect()
#   File "c:\Users\gdswm\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connection.py", line 279, in connect
#     self.sock = self._new_conn()
#                 ^^^^^^^^^^^^^^^^
#   File "c:\Users\gdswm\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connection.py", line 214, in _new_conn
#     raise NewConnectionError(
# urllib3.exceptions.NewConnectionError: <urllib3.connection.HTTPConnection object at 0x0000013B78419EE0>: Failed to establish a new connection: [WinError 10061] Nenhuma conexão pôde ser feita porque a máquina de destino as recusou ativamente
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "c:\Users\gdswm\AppData\Local\Programs\Python\Python312\Lib\threading.py", line 1075, in _bootstrap_inner
#     self.run()
#   File "c:\Users\gdswm\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel\ipkernel.py", line 766, in run_closure
#     _threading_Thread_run(self)
#   File "c:\Users\gdswm\AppData\Local\Programs\Python\Python312\Lib\threading.py", line 1012, in run
#     self._target(*self._args, **self._kwargs)
#   File "c:\Projetos\mineracao_arquivos_epstein_2026\extraction\downloader.py", line 76, in download_all_dataset
#     response = self.request(URL)
#                ^^^^^^^^^^^^^^^^^
#   File "c:\Projetos\mineracao_arquivos_epstein_2026\extraction\downloader.py", line 59, in request
#     return self.driver.request(method, URL, stream=stream, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\gdswm\AppData\Local\Programs\Python\Python312\Lib\site-packages\seleniumrequests\request.py", line 171, in request
#     if not get_tld(self.current_url) == requested_tld:
#                    ^^^^^^^^^^^^^^^^
#   File "c:\Users\gdswm\AppData\Local\Programs\Python\Python312\Lib\site-packages\selenium\webdriver\remote\webdriver.py", line 474, in current_url
#     return self.execute(Command.GET_CURRENT_URL)["value"]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\gdswm\AppData\Local\Programs\Python\Python312\Lib\site-packages\selenium\webdriver\remote\webdriver.py", line 382, in execute
#     response = self.command_executor.execute(driver_command, params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\gdswm\AppData\Local\Programs\Python\Python312\Lib\site-packages\selenium\webdriver\remote\remote_connection.py", line 404, in execute
#     return self._request(command_info[0], url, body=data)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\gdswm\AppData\Local\Programs\Python\Python312\Lib\site-packages\selenium\webdriver\remote\remote_connection.py", line 428, in _request
#     response = self._conn.request(method, url, body=body, headers=headers, timeout=self._client_config.timeout)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\gdswm\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\_request_methods.py", line 135, in request
#     return self.request_encode_url(
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\gdswm\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\_request_methods.py", line 182, in request_encode_url
#     return self.urlopen(method, url, **extra_kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\gdswm\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\poolmanager.py", line 443, in urlopen
#     response = conn.urlopen(method, u.request_uri, **kw)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\gdswm\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py", line 873, in urlopen
#     return self.urlopen(
#            ^^^^^^^^^^^^^
#   File "c:\Users\gdswm\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py", line 873, in urlopen
#     return self.urlopen(
#            ^^^^^^^^^^^^^
#   File "c:\Users\gdswm\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py", line 873, in urlopen
#     return self.urlopen(
#            ^^^^^^^^^^^^^
#   File "c:\Users\gdswm\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py", line 843, in urlopen
#     retries = retries.increment(
#               ^^^^^^^^^^^^^^^^^^
#   File "c:\Users\gdswm\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\util\retry.py", line 519, in increment
#     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# urllib3.exceptions.MaxRetryError: HTTPConnectionPool(host='localhost', port=57931): Max retries exceeded with url: /session/f903c385c6f19b29ee23eefe64b0858e/url (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x0000013B78419EE0>: Failed to establish a new connection: [WinError 10061] Nenhuma conexão pôde ser feita porque a máquina de destino as recusou ativamente'))

# %%
thread1.join()
thread2.join()
