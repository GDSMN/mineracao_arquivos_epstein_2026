# %%
import importlib
import downloader
import extractor
import threading

importlib.reload(downloader)
importlib.reload(extractor)
# Out:
# c:\Projetos\mineracao_arquivos_epstein_2026\extraction\extractor.py:35: SyntaxWarning: invalid escape sequence '\{'
#   with pdfplumber.open(self.download_dir + f'\{curr_file}') as pdf:
# c:\Projetos\mineracao_arquivos_epstein_2026\extraction\extractor.py:41: SyntaxWarning: invalid escape sequence '\{'
#   os.remove(self.download_dir + f'\{curr_file}')
# <module 'extractor' from 'c:\\Projetos\\mineracao_arquivos_epstein_2026\\extraction\\extractor.py'>

# %%
wd = downloader.Downloader()

# %%
extract = extractor.Extractor()

# %%
dataset=2

# %%
wd.get(f'https://www.justice.gov/epstein/doj-disclosures/data-set-{dataset}-files')
# Out:
# c:\Projetos\mineracao_arquivos_epstein_2026\extraction\downloader.py:78: SyntaxWarning: invalid escape sequence '\{'
#   with open(self.download_dir + f'\{curr_file}', 'wb') as f:
# ---------------------------------------------------------------------------
# InvalidSessionIdException                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 wd.get(f'https://www.justice.gov/epstein/doj-disclosures/data-set-{dataset}-files')
#
# File c:\Projetos\mineracao_arquivos_epstein_2026\extraction\downloader.py:62, in Downloader.get(self, URL)
#      61 def get(self, URL:str):
# ---> 62     return self.driver.get(URL)
#
# File c:\Users\gdswm\AppData\Local\Programs\Python\Python312\Lib\site-packages\selenium\webdriver\remote\webdriver.py:393, in WebDriver.get(self, url)
#     391 def get(self, url: str) -> None:
#     392     """Loads a web page in the current browser session."""
# --> 393     self.execute(Command.GET, {"url": url})
#
# File c:\Users\gdswm\AppData\Local\Programs\Python\Python312\Lib\site-packages\selenium\webdriver\remote\webdriver.py:384, in WebDriver.execute(self, driver_command, params)
#     382 response = self.command_executor.execute(driver_command, params)
#     383 if response:
# --> 384     self.error_handler.check_response(response)
#     385     response["value"] = self._unwrap_value(response.get("value", None))
#     386     return response
#
# File c:\Users\gdswm\AppData\Local\Programs\Python\Python312\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:232, in ErrorHandler.check_response(self, response)
#     230         alert_text = value["alert"].get("text")
#     231     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 232 raise exception_class(message, screen, stacktrace)
#
# InvalidSessionIdException: Message: invalid session id
# Stacktrace:
# 	chromedriver!GetHandleVerifier [0x2fb373+10553]
# 	chromedriver!GetHandleVerifier [0x2fb4a4+10684]
# 	chromedriver!(No symbol) [0x101c4e]
# 	chromedriver!(No symbol) [0x13f2c5]
# 	chromedriver!(No symbol) [0x16d726]
# 	chromedriver!(No symbol) [0x168c62]
# 	chromedriver!(No symbol) [0x168281]
# 	chromedriver!(No symbol) [0xd501e]
# 	chromedriver!(No symbol) [0xd55be]
# 	chromedriver!(No symbol) [0xd5a9d]
# 	chromedriver!GetHandleVerifier [0x57ddb4+292f94]
# 	chromedriver!GetHandleVerifier [0x57937d+28e55d]
# 	chromedriver!GetHandleVerifier [0x598215+2ad3f5]
# 	chromedriver!GetHandleVerifier [0x314c18+29df8]
# 	chromedriver!GetHandleVerifier [0x31c6fd+318dd]
# 	chromedriver!(No symbol) [0xd4b99]
# 	chromedriver!(No symbol) [0xd41e0]
# 	chromedriver!GetHandleVerifier [0x6e2bef+3f7dcf]
# 	KERNEL32!BaseThreadInitThunk [0x763e5d49+19]
# 	ntdll!RtlInitializeExceptionChain [0x77b2d83b+6b]
# 	ntdll!RtlGetAppContainerNamedObjectPath [0x77b2d7c1+231]
# 	(No symbol) [(nil)]

# %%
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException
import time

file_list = []

while True:
    file_links = wd.driver.find_elements(By.CSS_SELECTOR, 'div.item-list > ul > li > div.views-field.views-field-title > span.field-content > a')
    file_list = file_list + [item.get_attribute('innerHTML') for item in file_links]
    time.sleep(3)
    try:
        next_page = wd.driver.find_element(By.CSS_SELECTOR, 'nav.usa-pagination > ul > li.usa-pagination__arrow:nth-last-child(2) > a.usa-pagination__link.usa-pagination__next-page')
        wd.driver.execute_script('document.querySelector("nav.usa-pagination > ul > li.usa-pagination__arrow:nth-last-child(2) > a.usa-pagination__link.usa-pagination__next-page").click()')
    except NoSuchElementException:
        break
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 10
#       8 file_links = wd.driver.find_elements(By.CSS_SELECTOR, 'div.item-list > ul > li > div.views-field.views-field-title > span.field-content > a')
#       9 file_list = file_list + [item.get_attribute('innerHTML') for item in file_links]
# ---> 10 time.sleep(3)
#      11 try:
#      12     next_page = wd.driver.find_element(By.CSS_SELECTOR, 'nav.usa-pagination > ul > li.usa-pagination__arrow:nth-last-child(2) > a.usa-pagination__link.usa-pagination__next-page')
#
# KeyboardInterrupt:

# %%
file_list
# Out:
# ['EFTA02730265.pdf',
#  'EFTA02730267.pdf',
#  'EFTA02730271.pdf',
#  'EFTA02730274.pdf',
#  'EFTA02730468.pdf',
#  'EFTA02730469.pdf',
#  'EFTA02730471.pdf',
#  'EFTA02730473.pdf',
#  'EFTA02730477.pdf',
#  'EFTA02730481.pdf',
#  'EFTA02730483.pdf',
#  'EFTA02730485.pdf',
#  'EFTA02730486.pdf',
#  'EFTA02730741.pdf',
#  'EFTA02730996.pdf',
#  'EFTA02731018.pdf',
#  'EFTA02731023.pdf',
#  'EFTA02731039.pdf',
#  'EFTA02731069.pdf',
#  'EFTA02731082.pdf',
#  'EFTA02731168.pdf',
#  'EFTA02731200.pdf',
#  'EFTA02731226.pdf',
#  'EFTA02731254.pdf',
#  'EFTA02731260.pdf',
#  'EFTA02731341.pdf',
#  'EFTA02731361.pdf',
#  'EFTA02731393.pdf',
#  'EFTA02731410.pdf',
#  'EFTA02731411.pdf',
#  'EFTA02731412.pdf',
#  'EFTA02731413.pdf',
#  'EFTA02731414.pdf',
#  'EFTA02731415.pdf',
#  'EFTA02731416.pdf',
#  'EFTA02731417.pdf',
#  'EFTA02731418.pdf',
#  'EFTA02731419.pdf',
#  'EFTA02731420.pdf',
#  'EFTA02731433.pdf',
#  'EFTA02731465.pdf',
#  'EFTA02731473.pdf',
#  'EFTA02731475.pdf',
#  'EFTA02731477.pdf',
#  'EFTA02731478.pdf',
#  'EFTA02731479.pdf',
#  'EFTA02731480.pdf',
#  'EFTA02731482.pdf',
#  'EFTA02731484.pdf',
#  'EFTA02731485.pdf',
#  'EFTA02731486.pdf',
#  'EFTA02731488.pdf',
#  'EFTA02731490.pdf',
#  'EFTA02731497.pdf',
#  'EFTA02731498.pdf',
#  'EFTA02731499.pdf',
#  'EFTA02731500.pdf',
#  'EFTA02731501.pdf',
#  'EFTA02731507.pdf',
#  'EFTA02731508.pdf',
#  'EFTA02731509.pdf',
#  'EFTA02731510.pdf',
#  'EFTA02731511.pdf',
#  'EFTA02731512.pdf',
#  'EFTA02731514.pdf',
#  'EFTA02731515.pdf',
#  'EFTA02731517.pdf',
#  'EFTA02731521.pdf',
#  'EFTA02731524.pdf',
#  'EFTA02731525.pdf',
#  'EFTA02731526.pdf',
#  'EFTA02731528.pdf',
#  'EFTA02731529.pdf',
#  'EFTA02731552.pdf',
#  'EFTA02731556.pdf',
#  'EFTA02731576.pdf',
#  'EFTA02731577.pdf',
#  'EFTA02731578.pdf',
#  'EFTA02731582.pdf',
#  'EFTA02731583.pdf',
#  'EFTA02731587.pdf',
#  'EFTA02731593.pdf',
#  'EFTA02731604.pdf',
#  'EFTA02731608.pdf',
#  'EFTA02731612.pdf',
#  'EFTA02731615.pdf',
#  'EFTA02731617.pdf',
#  'EFTA02731618.pdf',
#  'EFTA02731623.pdf',
#  'EFTA02731628.pdf',
#  'EFTA02731630.pdf',
#  'EFTA02731632.pdf',
#  'EFTA02731633.pdf',
#  'EFTA02731636.pdf',
#  'EFTA02731637.pdf',
#  'EFTA02731638.pdf',
#  'EFTA02731640.pdf',
#  'EFTA02731643.pdf',
#  'EFTA02731644.pdf',
#  'EFTA02731646.pdf',
#  'EFTA02731648.pdf',
#  'EFTA02731651.pdf',
#  'EFTA02731655.pdf',
#  'EFTA02731659.pdf',
#  'EFTA02731660.pdf',
#  'EFTA02731662.pdf',
#  'EFTA02731682.pdf',
#  'EFTA02731684.pdf',
#  'EFTA02731687.pdf',
#  'EFTA02731688.pdf',
#  'EFTA02731689.pdf',
#  'EFTA02731697.pdf',
#  'EFTA02731699.pdf',
#  'EFTA02731703.pdf',
#  'EFTA02731704.pdf',
#  'EFTA02731705.pdf',
#  'EFTA02731706.pdf',
#  'EFTA02731707.pdf',
#  'EFTA02731708.pdf',
#  'EFTA02731709.pdf',
#  'EFTA02731710.pdf',
#  'EFTA02731711.pdf',
#  'EFTA02731712.pdf',
#  'EFTA02731713.pdf',
#  'EFTA02731715.pdf',
#  'EFTA02731718.pdf',
#  'EFTA02731721.pdf',
#  'EFTA02731724.pdf',
#  'EFTA02731726.pdf',
#  'EFTA02731727.pdf',
#  'EFTA02731728.pdf',
#  'EFTA02731729.pdf',
#  'EFTA02731732.pdf',
#  'EFTA02731733.pdf',
#  'EFTA02731734.pdf',
#  'EFTA02731735.pdf',
#  'EFTA02731736.pdf',
#  'EFTA02731737.pdf',
#  'EFTA02731754.pdf',
#  'EFTA02731755.pdf',
#  'EFTA02731757.pdf',
#  'EFTA02731762.pdf',
#  'EFTA02731765.pdf',
#  'EFTA02731771.pdf',
#  'EFTA02731774.pdf',
#  'EFTA02731775.pdf',
#  'EFTA02731777.pdf',
#  'EFTA02731778.pdf',
#  'EFTA02731779.pdf',
#  'EFTA02731780.pdf',
#  'EFTA02731781.pdf',
#  'EFTA02731783.pdf',
#  'EFTA02731790.pdf',
#  'EFTA02731812.pdf',
#  'EFTA02731852.pdf',
#  'EFTA02857524.pdf',
#  'EFTA02857729.pdf',
#  'EFTA02857732.pdf',
#  'EFTA02857763.pdf',
#  'EFTA02857810.pdf',
#  'EFTA02857840.pdf',
#  'EFTA02857844.pdf',
#  'EFTA02857845.pdf',
#  'EFTA02857849.pdf',
#  'EFTA02857857.pdf',
#  'EFTA02857860.pdf',
#  'EFTA02857863.pdf',
#  'EFTA02858445.pdf',
#  'EFTA02858453.pdf',
#  'EFTA02858461.pdf',
#  'EFTA02858465.pdf',
#  'EFTA02858481.pdf',
#  'EFTA02858491.pdf',
#  'EFTA02858495.pdf',
#  'EFTA02858497.pdf']

# %%
thread1 = threading.Thread(target=wd.download_all_dataset, args=(dataset,file_list))
thread2 = threading.Thread(target=extract.extract_from_files, args=(dataset,file_list))

# %%
thread1.start()
thread2.start()
# Out:
# Exceção: arquivo EFTA02730265.pdf
# Exceção: arquivo EFTA02730265.pdf
# Exceção: arquivo EFTA02730265.pdf
# Exceção: arquivo EFTA02730265.pdf
# Exceção: arquivo EFTA02730267.pdf
# Exceção: arquivo EFTA02730267.pdf
# Exceção: arquivo EFTA02730267.pdf
# Exceção: arquivo EFTA02730267.pdf
# Exceção: arquivo EFTA02730271.pdf
# Exceção: arquivo EFTA02730271.pdf
# Exceção: arquivo EFTA02730271.pdf
# Exceção: arquivo EFTA02730271.pdf
# Exceção: arquivo EFTA02730274.pdf
# Exceção: arquivo EFTA02730274.pdf
# Exceção: arquivo EFTA02730274.pdf
# Exceção: arquivo EFTA02730274.pdf
# Exceção: arquivo EFTA02730468.pdf
# Exceção: arquivo EFTA02730468.pdf
# Exceção: arquivo EFTA02730468.pdf
# Exceção: arquivo EFTA02730468.pdf
# Exceção: arquivo EFTA02730469.pdf
# Exceção: arquivo EFTA02730469.pdf
# Exceção: arquivo EFTA02730469.pdf
# Exceção: arquivo EFTA02730469.pdf
# Exceção: arquivo EFTA02730471.pdf
# Exceção: arquivo EFTA02730471.pdf
# Exceção: arquivo EFTA02730471.pdf
# Exceção: arquivo EFTA02730471.pdf
# Exceção: arquivo EFTA02730473.pdf
# Exceção: arquivo EFTA02730473.pdf
# Exceção: arquivo EFTA02730473.pdf
# Exceção: arquivo EFTA02730473.pdf
# Exceção: arquivo EFTA02730477.pdf
# Exceção: arquivo EFTA02730477.pdf
# Exceção: arquivo EFTA02730477.pdf
# Exceção: arquivo EFTA02730477.pdf
# Exceção: arquivo EFTA02730481.pdf
# Exceção: arquivo EFTA02730481.pdf
# Exceção: arquivo EFTA02730481.pdf
# Exceção: arquivo EFTA02730481.pdf
# Exceção: arquivo EFTA02730483.pdf
# Exceção: arquivo EFTA02730483.pdf
# Exceção: arquivo EFTA02730483.pdf
# Exceção: arquivo EFTA02730483.pdf
# Exceção: arquivo EFTA02730485.pdf
# Exceção: arquivo EFTA02730485.pdf
# Exceção: arquivo EFTA02730485.pdf
# Exceção: arquivo EFTA02730485.pdf
# Exceção: arquivo EFTA02730486.pdf
# Exceção: arquivo EFTA02730486.pdf
# Exceção: arquivo EFTA02730486.pdf
# Exceção: arquivo EFTA02730486.pdf
# Exceção: arquivo EFTA02730741.pdf
# Exceção: arquivo EFTA02730741.pdf
# Exceção: arquivo EFTA02730741.pdf
# Exceção: arquivo EFTA02730741.pdf
# Exceção: arquivo EFTA02730996.pdf
# Exceção: arquivo EFTA02730996.pdf
# Exceção: arquivo EFTA02730996.pdf
# Exceção: arquivo EFTA02730996.pdf
# Exceção: arquivo EFTA02731018.pdf
# Exceção: arquivo EFTA02731018.pdf
# Exceção: arquivo EFTA02731018.pdf
# Exceção: arquivo EFTA02731018.pdf
# Exceção: arquivo EFTA02731023.pdf
# Exceção: arquivo EFTA02731023.pdf
# Exceção: arquivo EFTA02731023.pdf
# Exceção: arquivo EFTA02731023.pdf
# Exceção: arquivo EFTA02731039.pdf
# Exceção: arquivo EFTA02731039.pdf
# Exceção: arquivo EFTA02731039.pdf
# Exceção: arquivo EFTA02731039.pdf
# Exceção: arquivo EFTA02731069.pdf
# Exceção: arquivo EFTA02731069.pdf
# Exceção: arquivo EFTA02731069.pdf
# Exceção: arquivo EFTA02731069.pdf
# Exceção: arquivo EFTA02731082.pdf
# Exceção: arquivo EFTA02731082.pdf
# Exceção: arquivo EFTA02731082.pdf
# Exceção: arquivo EFTA02731082.pdf
# Exceção: arquivo EFTA02731168.pdf
# Exceção: arquivo EFTA02731168.pdf
# Exceção: arquivo EFTA02731168.pdf
# Exceção: arquivo EFTA02731168.pdf
# Exceção: arquivo EFTA02731200.pdf
# Exceção: arquivo EFTA02731200.pdf
# Exceção: arquivo EFTA02731200.pdf
# Exceção: arquivo EFTA02731200.pdf
# Exceção: arquivo EFTA02731226.pdf
# Exceção: arquivo EFTA02731226.pdf
# Exceção: arquivo EFTA02731226.pdf
# Exceção: arquivo EFTA02731226.pdf
# Exceção: arquivo EFTA02731254.pdf
# Exceção: arquivo EFTA02731254.pdf
# Exceção: arquivo EFTA02731254.pdf
# Exceção: arquivo EFTA02731254.pdf
# Exceção: arquivo EFTA02731260.pdf
# Exceção: arquivo EFTA02731260.pdf
# Exceção: arquivo EFTA02731260.pdf
# Exceção: arquivo EFTA02731260.pdf
# Exceção: arquivo EFTA02731341.pdf
# Exceção: arquivo EFTA02731341.pdf
# Exceção: arquivo EFTA02731341.pdf
# Exceção: arquivo EFTA02731341.pdf
# Exceção: arquivo EFTA02731361.pdf
# Exceção: arquivo EFTA02731361.pdf
# Exceção: arquivo EFTA02731361.pdf
# Exceção: arquivo EFTA02731361.pdf
# Exceção: arquivo EFTA02731393.pdf
# Exceção: arquivo EFTA02731393.pdf
# Exceção: arquivo EFTA02731393.pdf
# Exceção: arquivo EFTA02731393.pdf
# Exceção: arquivo EFTA02731410.pdf
# Exceção: arquivo EFTA02731410.pdf
# Exceção: arquivo EFTA02731410.pdf
# Exceção: arquivo EFTA02731410.pdf
# Exceção: arquivo EFTA02731411.pdf
# Exceção: arquivo EFTA02731411.pdf
# Exceção: arquivo EFTA02731411.pdf
# Exceção: arquivo EFTA02731411.pdf
# Exceção: arquivo EFTA02731412.pdf
# Exceção: arquivo EFTA02731412.pdf
# Exceção: arquivo EFTA02731412.pdf
# Exceção: arquivo EFTA02731412.pdf
# Exceção: arquivo EFTA02731413.pdf
# Exceção: arquivo EFTA02731413.pdf
# Exceção: arquivo EFTA02731413.pdf
# Exceção: arquivo EFTA02731413.pdf
# Exceção: arquivo EFTA02731414.pdf
# Exceção: arquivo EFTA02731414.pdf

# %%
thread1.join()
thread2.join()
